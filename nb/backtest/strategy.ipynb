# %%
import nb_setup 
import importlib
importlib.reload(nb_setup)
nb_setup.init()
# Out:
# Added project root to sys.path: /Users/falconlin/Development/backtesting-playground/trading
# Changed current working directory to: /Users/falconlin/Development/backtesting-playground/trading
# Initialized project with base directory: /Users/falconlin/Development/backtesting-playground/trading

# %%
import pandas as pd
from settings import DATA_DIR

df = pd.read_csv(DATA_DIR / "all_ranked.csv", index_col=[0])
df.head()
# Out:
#                  start_time  average_rank  \
# symbol
# BTC     2024-02-10 00:00:00           NaN
# BTC     2024-02-10 00:15:00          46.0
# BTC     2024-02-10 00:30:00          23.0
# BTC     2024-02-10 00:45:00          18.0
# BTC     2024-02-10 01:00:00          13.0
#
#         rank_rolling_accumulated_pct_change  rank_rolling_variance_pct_change  \
# symbol
# BTC                                     NaN                               NaN
# BTC                                    46.0                               NaN
# BTC                                    42.0                               4.0
# BTC                                    34.0                               2.0
# BTC                                    24.0                               2.0
#
#            open    close
# symbol
# BTC     47166.0  47244.0
# BTC     47244.0  47204.0
# BTC     47204.0  47147.0
# BTC     47146.0  47116.0
# BTC     47122.0  47110.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164217 entries, BTC to LDO
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   start_time                           164217 non-null  object
#  1   average_rank                         164160 non-null  float64
#  2   rank_rolling_accumulated_pct_change  164160 non-null  float64
#  3   rank_rolling_variance_pct_change     164103 non-null  float64
#  4   open                                 164217 non-null  float64
#  5   close                                164217 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 8.8+ MB

# %%
import numpy as np
import pandas as pd


def _initialize(df_final):
    # Initial principal amount
    principal = 1_000_000

    # Assuming df_final is your prepared DataFrame
    df_final["start_time"] = pd.to_datetime(df_final["start_time"])
    df_final = df_final.sort_values(by=["start_time", "average_rank"])

    # Find unique timestamps
    timestamps = df_final["start_time"].unique()

    return df_final, principal, timestamps


def _get_intervals(
    df_final,
    current_time,
    i,
    trading_interval,
    timestamps,
    verbose,
):
    """
    Inputs:
    df_final: DataFrame
    current_time: Timestamp
    i: int  # Index of the current loop
    trading_interval: DataFrame
    timestamps: list of start_times
    verbose: bool
    """
    if i + trading_interval < len(timestamps):
        close_time = timestamps[i + trading_interval]
    else:
        close_time = timestamps[-1]

    if verbose:
        print("Current time:", current_time)
        print("Close time:", close_time)

    # Filter the DataFrame for the current timestamp
    last_interval = df_final[
        df_final["start_time"] == current_time - pd.Timedelta(minutes=15)
    ]

    current_interval = df_final[(df_final["start_time"] == current_time)]

    if verbose:
        print(
            # current_interval.loc[:, ["start_time", "open", "close"]].head(),
        )

    return last_interval, current_interval, close_time


def calculate_returns(
    df_final,
    trading_interval=1,
    verbose=False,
    loop=None,
    slippage_and_cost=0.003,
    transaction_cost=0.00025,
):
    # Initialize
    df_final, principal, timestamps = _initialize(df_final)
    results = []

    # Adjust loop to step through timestamps according to trading_interval
    current = -1
    for i in range(0, len(timestamps) - trading_interval, trading_interval):
        current += 1
        if loop is not None and current == loop:
            break

        current_time = timestamps[i]
        print("---------------------------------------------")
        print("Current time:", current_time, i)
        print("---------------------------------------------")

        # Ensure we do not go out of bounds for the last interval
        last_interval, current_interval, close_time = _get_intervals(
            df_final,
            current_time,
            i,
            trading_interval,
            timestamps,
            verbose,
        )
        if current_interval.empty or last_interval.empty:
            print("Empty interval, skipping")
            continue

        # Calculate investment per coin
        investment_per_coin = principal / 20  # Divided among top 10 and bottom 10

        # For the top 10 and bottom 10, we need the open price at current_time and close price at close_time
        top_10 = last_interval.head(10).copy()
        bottom_10 = last_interval.tail(10).copy()

        if (
            np.isnan(top_10["average_rank"]).all()
            or np.isnan(bottom_10["average_rank"]).all()
            or i == 2
        ):
            interval_return = 0
            principal += interval_return
        else:
            # top 10 ranked coins prices
            top_10_open_prices = current_interval.loc[top_10.index, "open"].values
            bottom_10_open_prices = current_interval.loc[bottom_10.index, "open"].values

            # Get closing prices at close_time
            future_interval = df_final[
                df_final["start_time"] == close_time - pd.Timedelta(minutes=15)
            ]
            if future_interval.empty:
                print("Empty future interval, skipping")
                continue
            top_10_close_prices = future_interval.loc[top_10.index, "close"].values
            bottom_10_close_prices = future_interval.loc[
                bottom_10.index, "close"
            ].values

            if verbose:
                print("top_10.shape", top_10.shape)
                print("bottom_10.shape", bottom_10.shape)
                print("last_interval.shape", last_interval.shape)
                print("current_interval.shape", current_interval.shape)
                print("future_interval.shape", future_interval.shape)
                print("top_10_open_prices", len(top_10_open_prices))
                print("top_10_close_prices", len(top_10_close_prices))
                print("bottom_10_open_prices", len(bottom_10_open_prices))
                print("bottom_10_close_prices", len(bottom_10_close_prices))
                # print(bottom_10.loc[:, ["start_time", "open", "close"]].head())
                # print(current_interval.loc[:, ["start_time", "open", "close"]].head())
                # print(future_interval.loc[:, ["start_time", "open", "close"]].head())

            # Long the top 10

            long_asset = (
                (
                    -top_10_open_prices
                    * (1 + slippage_and_cost)
                    # - top_10_open_prices * (1 + slippage_and_cost) * (transaction_cost)
                )
                * (investment_per_coin)
                / (top_10_open_prices * (1 + slippage_and_cost))
            )

            sell_longed_asset = (
                (
                    +top_10_close_prices
                    * (1 - slippage_and_cost)
                    # - top_10_close_prices * (1 - slippage_and_cost) * (transaction_cost)
                )
                * (investment_per_coin)
                / (top_10_open_prices * (1 + slippage_and_cost))
            )
            long_returns = long_asset + sell_longed_asset

            # Short the bottom 10
            short_asset = (
                (
                    bottom_10_open_prices
                    * (1 - slippage_and_cost)
                    # - bottom_10_open_prices
                    # * (1 - slippage_and_cost)
                    # * (transaction_cost)
                )* (investment_per_coin)
                / (bottom_10_open_prices * (1 - slippage_and_cost))
            ) 

            buy_shorted_asset = (
                (
                    -bottom_10_close_prices
                    * (1 + slippage_and_cost)
                    # - bottom_10_close_prices
                    # * (1 + slippage_and_cost)
                    # * (transaction_cost)
                )* (investment_per_coin)
                / (bottom_10_open_prices * (1 - slippage_and_cost))
            ) 
            short_returns = short_asset + buy_shorted_asset

            # Calculate returns
            interval_return = long_returns.sum() + short_returns.sum()
            principal += interval_return

            if verbose:
                print("=========Verbose Section===========")
                print(
                    "top_10_open_prices", top_10_open_prices * (1 + slippage_and_cost)
                )
                print(
                    "top_10_close_prices", top_10_close_prices * (1 - slippage_and_cost)
                )
                print(
                    "bottom_10_open_prices",
                    bottom_10_open_prices * (1 - slippage_and_cost),
                )
                print(
                    "bottom_10_close_prices",
                    bottom_10_close_prices * (1 + slippage_and_cost),
                )
                print("long_asset", long_asset)
                print("sell_longed_asset", sell_longed_asset)
                print("long_returns", long_returns)
                print("short_asset", short_asset)
                print("buy_shorted_asset", buy_shorted_asset)
                print("short_returns", short_returns)

        results.append(
            {
                "timestamp": current_time,
                "return": interval_return,
                "principal": principal,
            }
        )

        print("---------------------------------------------")
        print(
            f"For interval {i//trading_interval} starting at {current_time}: Long {top_10.index.values}, Short {bottom_10.index.values}"
        )
        print(
            f"For interval {i//trading_interval} starting at {current_time}: Long {top_10['average_rank'].values}, Short {bottom_10['average_rank'].values}"
        )
        print(
            f"In this interval, the return is {interval_return}, new principal is {principal}"
        )

    # Summarize results
    results_df = pd.DataFrame(results)
    if "return" not in results_df.columns:
        print("No returns calculated")
        return results_df
    total_performance = results_df["return"].sum()
    print("Total simulated return over the period:", total_performance)
    return results_df


# Example usage, assuming df is your DataFrame
results_df = calculate_returns(
    df,
    trading_interval=92,
    loop=None,
    verbose=False,
    slippage_and_cost=0.003,
    transaction_cost=0,
)  # Adjust trading_interval as needed
# Out:
# ---------------------------------------------
# Current time: 2024-02-10 00:00:00 0
# ---------------------------------------------
# Empty interval, skipping
# ---------------------------------------------
# Current time: 2024-02-10 23:00:00 92
# ---------------------------------------------
# ---------------------------------------------
# For interval 1 starting at 2024-02-10 23:00:00: Long ['BTC' 'MKR' 'ETH' 'LTC' 'DOGE' 'BNB' 'kSHIB' 'XRP' 'SOL' 'ADA'], Short ['ORDI' 'BLUR' 'JUP' 'OP' 'RNDR' 'RUNE' 'SUI' 'SEI' 'ALT' 'AI']
# For interval 1 starting at 2024-02-10 23:00:00: Long [10.5 11.  15.  15.5 16.  16.5 16.5 17.5 18.  19. ], Short [40.5 41.  41.5 41.5 42.  42.  46.  50.  50.  50.5]
# In this interval, the return is -16571.026073202236, new principal is 983428.9739267977
# ---------------------------------------------
# Current time: 2024-02-11 22:00:00 184
# ---------------------------------------------
# ---------------------------------------------
# For interval 2 starting at 2024-02-11 22:00:00: Long ['BTC' 'MKR' 'ETH' 'XRP' 'LTC' 'DOGE' 'kSHIB' 'BNB' 'LINK' 'UNI'], Short ['ORDI' 'LDO' 'TIA' 'RNDR' 'BLUR' 'DYM' 'DYDX' 'ALT' 'SUI' 'SEI']
# For interval 2 starting at 2024-02-11 22:00:00: Long [10.  11.  11.5 13.5 14.5 16.5 17.5 18.  18.  20. ], Short [37.  37.5 40.  40.  40.5 41.  41.  46.  47.5 50. ]
# In this interval, the return is -22985.816898820063, new principal is 960443.1570279776
# ---------------------------------------------
# Current time: 2024-02-12 21:00:00 276
# ---------------------------------------------
# ---------------------------------------------
# For interval 3 starting at 2024-02-12 21:00:00: Long ['ETH' 'BTC' 'MKR' 'LTC' 'LINK' 'XRP' 'MATIC' 'BNB' 'ARB' 'kSHIB'], Short ['kBONK' 'MANTA' 'DYDX' 'BLUR' 'RNDR' 'ALT' 'TIA' 'DYM' 'JUP' 'SUI']
# For interval 3 starting at 2024-02-12 21:00:00: Long [11.5 12.5 14.5 18.5 19.  21.  22.  22.5 22.5 22.5], Short [34.  35.  35.5 39.5 41.  42.5 43.5 45.  46.5 46.5]
# In this interval, the return is -12818.530187291843, new principal is 947624.6268406858
# ---------------------------------------------
# Current time: 2024-02-13 20:00:00 368
# ---------------------------------------------
# ---------------------------------------------
# For interval 4 starting at 2024-02-13 20:00:00: Long ['ETH' 'BTC' 'MKR' 'LINK' 'XRP' 'FET' 'LDO' 'BNB' 'STX' 'kSHIB'], Short ['OP' 'RUNE' 'NFTI' 'INJ' 'TIA' 'kBONK' 'JUP' 'MANTA' 'ALT' 'DYM']
# For interval 4 starting at 2024-02-13 20:00:00: Long [12.  13.  14.  19.  20.  21.  22.  22.5 23.  23.5], Short [34.5 38.5 39.  39.  43.  43.5 45.5 46.  47.  51. ]
# In this interval, the return is -22040.742886125023, new principal is 925583.8839545608
# ---------------------------------------------
# Current time: 2024-02-14 19:00:00 460
# ---------------------------------------------
# ---------------------------------------------
# For interval 5 starting at 2024-02-14 19:00:00: Long ['ETH' 'BTC' 'MKR' 'YGG' 'LINK' 'STX' 'WLD' 'BNB' 'GALA' 'AVAX'], Short ['ATOM' 'DYDX' 'RNDR' 'MANTA' 'PEOPLE' 'kBONK' 'OP' 'TIA' 'INJ' 'JUP']
# For interval 5 starting at 2024-02-14 19:00:00: Long [12.  13.5 20.5 21.  22.5 23.  24.  24.  24.  24.5], Short [33.5 34.5 35.5 35.5 36.5 38.5 39.  43.  43.  44. ]
# In this interval, the return is 3719.380852733593, new principal is 929303.2648072945
# ---------------------------------------------
# Current time: 2024-02-15 18:00:00 552
# ---------------------------------------------
# ---------------------------------------------
# For interval 6 starting at 2024-02-15 18:00:00: Long ['ETH' 'BTC' 'BNB' 'GALA' 'UNI' 'APT' 'ADA' 'CAKE' 'kSHIB' 'DOT'], Short ['kBONK' 'ALT' 'BCH' 'MANTA' 'PEOPLE' 'SUI' 'TIA' 'RNDR' 'INJ' 'JUP']
# For interval 6 starting at 2024-02-15 18:00:00: Long [10.  13.5 14.  17.5 19.  19.5 19.5 22.  23.  24. ], Short [35.5 37.  37.5 37.5 38.  41.5 42.5 43.  45.  46.5]
# In this interval, the return is -15192.386858847574, new principal is 914110.8779484469
# ---------------------------------------------
# Current time: 2024-02-16 17:00:00 644
# ---------------------------------------------
# ---------------------------------------------
# For interval 7 starting at 2024-02-16 17:00:00: Long ['BNB' 'ETH' 'BTC' 'UNI' 'MATIC' 'YGG' 'XRP' 'GALA' 'FET' 'ADA'], Short ['DYDX' 'SUI' 'MANTA' 'TIA' 'OP' 'kBONK' 'DYM' 'INJ' 'ENS' 'JUP']
# For interval 7 starting at 2024-02-16 17:00:00: Long [ 8.5  9.  10.5 16.  18.  18.  18.  20.  20.5 21.5], Short [36.  41.5 41.5 42.  42.5 42.5 44.  44.5 45.  47.5]
# In this interval, the return is 1146.5646054521785, new principal is 915257.442553899
# ---------------------------------------------
# Current time: 2024-02-17 16:00:00 736
# ---------------------------------------------
# ---------------------------------------------
# For interval 8 starting at 2024-02-17 16:00:00: Long ['ETH' 'BNB' 'BTC' 'UNI' 'MATIC' 'FIL' 'XRP' 'ADA' 'YGG' 'AAVE'], Short ['OP' 'MINA' 'TIA' 'INJ' 'MANTA' 'XAI' 'ENS' 'JUP' 'kBONK' 'DYM']
# For interval 8 starting at 2024-02-17 16:00:00: Long [ 9.5 10.5 11.5 11.5 14.5 18.  18.5 20.  20.5 21. ], Short [39.  40.5 41.5 42.  44.  44.5 47.  47.5 52.  53.5]
# In this interval, the return is -23989.177728532617, new principal is 891268.2648253664
# ---------------------------------------------
# Current time: 2024-02-18 15:00:00 828
# ---------------------------------------------
# ---------------------------------------------
# For interval 9 starting at 2024-02-18 15:00:00: Long ['ETH' 'BNB' 'UNI' 'MATIC' 'ADA' 'BTC' 'GALA' 'DOT' 'AAVE' 'YGG'], Short ['AVAX' 'BCH' 'NFTI' 'MANTA' 'JUP' 'OP' 'TIA' 'ENS' 'kBONK' 'DYM']
# For interval 9 starting at 2024-02-18 15:00:00: Long [10.5 13.5 15.  15.5 16.  16.5 18.  18.5 21.5 22. ], Short [37.  38.5 41.  41.  41.5 41.5 42.  44.  48.5 50.5]
# In this interval, the return is -4595.705446099164, new principal is 886672.5593792673
# ---------------------------------------------
# Current time: 2024-02-19 14:00:00 920
# ---------------------------------------------
# ---------------------------------------------
# For interval 10 starting at 2024-02-19 14:00:00: Long ['ETH' 'MATIC' 'UNI' 'BNB' 'GALA' 'ADA' 'FTM' 'BTC' 'FIL' 'MKR'], Short ['OP' 'RUNE' 'PYTH' 'INJ' 'TIA' 'SUI' 'kBONK' 'MINA' 'ENS' 'DYM']
# For interval 10 starting at 2024-02-19 14:00:00: Long [12.  14.5 18.  19.  19.5 20.  21.  21.5 22.  22.5], Short [36.  36.5 37.5 39.  40.5 40.5 42.  43.  43.  50. ]
# In this interval, the return is 11011.28743830644, new principal is 897683.8468175738
# ---------------------------------------------
# Current time: 2024-02-20 13:00:00 1012
# ---------------------------------------------
# ---------------------------------------------
# For interval 11 starting at 2024-02-20 13:00:00: Long ['ETH' 'BNB' 'XRP' 'MATIC' 'UNI' 'BTC' 'ADA' 'YGG' 'DOGE' 'GMT'], Short ['ENS' 'SUI' 'MINA' 'AI' 'kBONK' 'TIA' 'PYTH' 'DYM' 'WIF' 'MAVIA']
# For interval 11 starting at 2024-02-20 13:00:00: Long [11.  12.  14.  15.  15.  16.  17.  19.5 20.  20. ], Short [38.  38.5 39.  39.5 41.  41.5 44.5 45.5 53.  57. ]
# In this interval, the return is 6749.1796832689215, new principal is 904433.0265008427
# ---------------------------------------------
# Current time: 2024-02-21 12:00:00 1104
# ---------------------------------------------
# ---------------------------------------------
# For interval 12 starting at 2024-02-21 12:00:00: Long ['ETH' 'BNB' 'BTC' 'XRP' 'UNI' 'LTC' 'DOGE' 'MATIC' 'kSHIB' 'MKR'], Short ['TIA' 'JUP' 'BLUR' 'MINA' 'kBONK' 'DYM' 'PYTH' 'AI' 'MAVIA' 'WIF']
# For interval 12 starting at 2024-02-21 12:00:00: Long [ 6.5  8.  11.5 11.5 13.5 15.  15.5 15.5 15.5 17. ], Short [39.5 40.5 42.  43.  46.5 47.  47.  47.  50.5 56. ]
# In this interval, the return is -6102.229421953569, new principal is 898330.7970788891
# ---------------------------------------------
# Current time: 2024-02-22 11:00:00 1196
# ---------------------------------------------
# ---------------------------------------------
# For interval 13 starting at 2024-02-22 11:00:00: Long ['ETH' 'BNB' 'LTC' 'BTC' 'MKR' 'UNI' 'XRP' 'BCH' 'DOGE' 'MATIC'], Short ['MINA' 'kPEPE' 'BLUR' 'MAVIA' 'kBONK' 'JUP' 'PYTH' 'SEI' 'DYM' 'WIF']
# For interval 13 starting at 2024-02-22 11:00:00: Long [ 7.5  8.  12.  13.5 14.  14.5 15.  15.5 16.5 16.5], Short [40.  42.  42.  44.5 45.  46.5 47.5 50.  50.5 56. ]
# In this interval, the return is -5556.67083404358, new principal is 892774.1262448456
# ---------------------------------------------
# Current time: 2024-02-23 10:00:00 1288
# ---------------------------------------------
# ---------------------------------------------
# For interval 14 starting at 2024-02-23 10:00:00: Long ['BNB' 'ETH' 'BTC' 'BCH' 'LTC' 'DOGE' 'kSHIB' 'MKR' 'CAKE' 'XRP'], Short ['MINA' 'ENS' 'BLUR' 'JUP' 'PYTH' 'kBONK' 'DYM' 'SEI' 'MAVIA' 'WIF']
# For interval 14 starting at 2024-02-23 10:00:00: Long [ 7.5  9.  10.  12.5 15.  16.  17.  17.5 18.5 19.5], Short [38.5 39.5 39.5 40.  43.  45.5 46.  51.  54.5 55.5]
# In this interval, the return is 10814.74209167937, new principal is 903588.8683365249
# ---------------------------------------------
# Current time: 2024-02-24 09:00:00 1380
# ---------------------------------------------
# ---------------------------------------------
# For interval 15 starting at 2024-02-24 09:00:00: Long ['ETH' 'BNB' 'ATOM' 'LTC' 'BTC' 'DOGE' 'DOT' 'BCH' 'kSHIB' 'AAVE'], Short ['INJ' 'BLUR' 'PYTH' 'ORDI' 'STX' 'kBONK' 'SEI' 'MAVIA' 'DYM' 'WIF']
# For interval 15 starting at 2024-02-24 09:00:00: Long [10.5 11.  14.5 15.  17.  17.  17.  17.5 19.  19. ], Short [38.  38.5 39.5 40.  40.5 40.5 49.  49.5 50.  55. ]
# In this interval, the return is -25857.578731564186, new principal is 877731.2896049607
# ---------------------------------------------
# Current time: 2024-02-25 08:00:00 1472
# ---------------------------------------------
# ---------------------------------------------
# For interval 16 starting at 2024-02-25 08:00:00: Long ['ETH' 'BNB' 'BTC' 'DOGE' 'LTC' 'BCH' 'XRP' 'NEAR' 'kSHIB' 'GALA'], Short ['MANTA' 'JUP' 'PYTH' 'kBONK' 'INJ' 'SEI' 'AI' 'DYM' 'WIF' 'MAVIA']
# For interval 16 starting at 2024-02-25 08:00:00: Long [ 9.  10.5 14.5 15.  16.  16.5 18.5 19.5 19.5 20.5], Short [37.  38.  39.5 41.  44.5 46.  46.5 48.  54.5 56. ]
# In this interval, the return is -6206.801819901542, new principal is 871524.4877850591
# ---------------------------------------------
# Current time: 2024-02-26 07:00:00 1564
# ---------------------------------------------
# ---------------------------------------------
# For interval 17 starting at 2024-02-26 07:00:00: Long ['BNB' 'ETH' 'kSHIB' 'LTC' 'BTC' 'DOGE' 'BCH' 'YGG' 'DOT' 'XRP'], Short ['MANTA' 'BLUR' 'STX' 'PYTH' 'JUP' 'WIF' 'SEI' 'DYM' 'AI' 'MAVIA']
# For interval 17 starting at 2024-02-26 07:00:00: Long [ 9.   9.5 14.  14.  15.  15.  15.5 17.5 17.5 18.5], Short [39.  41.  41.5 42.5 45.  46.  47.  48.5 51.5 56.5]
# In this interval, the return is -35431.388484686046, new principal is 836093.0993003731
# ---------------------------------------------
# Current time: 2024-02-27 06:00:00 1656
# ---------------------------------------------
# ---------------------------------------------
# For interval 18 starting at 2024-02-27 06:00:00: Long ['BNB' 'ETH' 'BTC' 'BCH' 'LTC' 'kSHIB' 'RUNE' 'ATOM' 'DOGE' 'NEAR'], Short ['TIA' 'JUP' 'SEI' 'ENS' 'BLUR' 'MANTA' 'INJ' 'DYM' 'AI' 'MAVIA']
# For interval 18 starting at 2024-02-27 06:00:00: Long [11.  11.5 12.  12.  15.  18.  19.  19.  19.5 20. ], Short [37.5 38.  40.  40.5 42.  43.  43.5 46.5 49.  54.5]
# In this interval, the return is -1169.4896109179463, new principal is 834923.6096894551
# ---------------------------------------------
# Current time: 2024-02-28 05:00:00 1748
# ---------------------------------------------
# ---------------------------------------------
# For interval 19 starting at 2024-02-28 05:00:00: Long ['BNB' 'BTC' 'RUNE' 'DOGE' 'ETH' 'LTC' 'ATOM' 'BCH' 'DOT' 'XRP'], Short ['FET' 'BLUR' 'WLD' 'SEI' 'MANTA' 'AI' 'DYM' 'XAI' 'ALT' 'MAVIA']
# For interval 19 starting at 2024-02-28 05:00:00: Long [11.  12.  12.  12.5 14.  15.5 16.5 17.5 19.5 19.5], Short [39.5 41.  43.  43.5 44.5 45.  46.  48.5 49.5 53. ]
# In this interval, the return is 23134.05324780532, new principal is 858057.6629372605
# ---------------------------------------------
# Current time: 2024-02-29 04:00:00 1840
# ---------------------------------------------
# ---------------------------------------------
# For interval 20 starting at 2024-02-29 04:00:00: Long ['BTC' 'ETH' 'ATOM' 'SOL' 'RUNE' 'FTM' 'BNB' 'LTC' 'kSHIB' 'YGG'], Short ['ENS' 'FIL' 'SEI' 'DYM' 'MANTA' 'AI' 'XAI' 'WLD' 'ALT' 'MAVIA']
# For interval 20 starting at 2024-02-29 04:00:00: Long [ 9. 14. 16. 17. 17. 17. 19. 19. 20. 20.], Short [37.5 40.  40.5 41.5 42.  47.  47.5 48.5 52.  53. ]
# In this interval, the return is 13262.804025105885, new principal is 871320.4669623664
# ---------------------------------------------
# Current time: 2024-03-01 03:00:00 1932
# ---------------------------------------------
# ---------------------------------------------
# For interval 21 starting at 2024-03-01 03:00:00: Long ['LTC' 'BTC' 'SOL' 'ETH' 'BCH' 'ATOM' 'AVAX' 'FTM' 'BNB' 'ADA'], Short ['FIL' 'PYTH' 'MANTA' 'DYM' 'RNDR' 'AI' 'XAI' 'ALT' 'WLD' 'MAVIA']
# For interval 21 starting at 2024-03-01 03:00:00: Long [10.  11.5 16.  16.5 17.5 17.5 18.  19.5 20.  20. ], Short [38.5 39.  39.5 41.5 43.5 44.5 46.  50.  51.5 53. ]
# In this interval, the return is 4447.036327026137, new principal is 875767.5032893925
# ---------------------------------------------
# Current time: 2024-03-02 02:00:00 2024
# ---------------------------------------------
# ---------------------------------------------
# For interval 22 starting at 2024-03-02 02:00:00: Long ['BTC' 'ETH' 'ADA' 'LTC' 'ATOM' 'FTM' 'LINK' 'XRP' 'AVAX' 'BCH'], Short ['ENS' 'AI' 'MANTA' 'RNDR' 'DYM' 'XAI' 'ALT' 'UNI' 'WLD' 'MAVIA']
# For interval 22 starting at 2024-03-02 02:00:00: Long [13.5 14.5 14.5 14.5 16.  17.5 18.  18.5 19.  19. ], Short [37.  37.  38.  39.  40.  45.5 47.  50.5 51.5 52.5]
# In this interval, the return is 457.94934147231106, new principal is 876225.4526308648
# ---------------------------------------------
# Current time: 2024-03-03 01:00:00 2116
# ---------------------------------------------
# ---------------------------------------------
# For interval 23 starting at 2024-03-03 01:00:00: Long ['LTC' 'BTC' 'ATOM' 'DOT' 'ETH' 'FTM' 'ADA' 'LINK' 'XRP' 'BNB'], Short ['SEI' 'DYM' 'RNDR' 'NFTI' 'BLUR' 'UNI' 'ALT' 'XAI' 'MAVIA' 'WLD']
# For interval 23 starting at 2024-03-03 01:00:00: Long [12.5 13.  16.  16.5 17.  17.5 17.5 18.  18.5 19. ], Short [38.5 38.5 40.5 42.  42.  42.5 43.5 45.  52.  52.5]
# In this interval, the return is 13882.061555828768, new principal is 890107.5141866936
# ---------------------------------------------
# Current time: 2024-03-04 00:00:00 2208
# ---------------------------------------------
# ---------------------------------------------
# For interval 24 starting at 2024-03-04 00:00:00: Long ['BTC' 'LTC' 'DOT' 'ATOM' 'ETH' 'XRP' 'ADA' 'FTM' 'BNB' 'LINK'], Short ['MANTA' 'SEI' 'BLUR' 'NFTI' 'DYM' 'ALT' 'AI' 'XAI' 'WLD' 'MAVIA']
# For interval 24 starting at 2024-03-04 00:00:00: Long [12.  13.5 14.5 15.5 17.  17.5 17.5 18.  18.5 19.5], Short [37.  38.  39.  41.  41.  42.  42.  44.  51.  51.5]
# In this interval, the return is 13057.06240435395, new principal is 903164.5765910476
# ---------------------------------------------
# Current time: 2024-03-04 23:00:00 2300
# ---------------------------------------------
# ---------------------------------------------
# For interval 25 starting at 2024-03-04 23:00:00: Long ['BTC' 'ETH' 'ATOM' 'DOT' 'XRP' 'LTC' 'ADA' 'BNB' 'LINK' 'MATIC'], Short ['DYM' 'SUI' 'PYTH' 'NFTI' 'AI' 'SEI' 'ALT' 'XAI' 'WLD' 'MAVIA']
# For interval 25 starting at 2024-03-04 23:00:00: Long [ 9.5 13.5 16.  16.  16.  16.  16.5 18.5 19.5 20.5], Short [37.5 38.  38.5 39.5 41.5 42.5 42.5 43.  48.5 51.5]
# In this interval, the return is -2948.1349681884603, new principal is 900216.4416228591
# ---------------------------------------------
# Current time: 2024-03-05 22:00:00 2392
# ---------------------------------------------
# ---------------------------------------------
# For interval 26 starting at 2024-03-05 22:00:00: Long ['BTC' 'ETH' 'BNB' 'ATOM' 'LTC' 'DOT' 'XRP' 'SOL' 'ARB' 'ADA'], Short ['PYTH' 'YGG' 'GALA' 'INJ' 'AI' 'ALT' 'SEI' 'XAI' 'WLD' 'MAVIA']
# For interval 26 starting at 2024-03-05 22:00:00: Long [ 8.5 12.5 15.5 15.5 15.5 16.5 17.  18.5 19.5 20. ], Short [38.  39.5 40.5 41.5 41.5 42.  42.5 43.  48.5 52. ]
# In this interval, the return is -7817.620111461976, new principal is 892398.8215113971
# ---------------------------------------------
# Current time: 2024-03-06 21:00:00 2484
# ---------------------------------------------
# ---------------------------------------------
# For interval 27 starting at 2024-03-06 21:00:00: Long ['ETH' 'ATOM' 'BTC' 'DOT' 'AAVE' 'LTC' 'MATIC' 'XRP' 'BNB' 'NEAR'], Short ['STX' 'PYTH' 'ORDI' 'ALT' 'AI' 'INJ' 'SEI' 'YGG' 'MAVIA' 'WLD']
# For interval 27 starting at 2024-03-06 21:00:00: Long [12.5 14.  15.  16.  16.5 18.5 19.5 19.5 20.5 21. ], Short [38.  39.  39.5 39.5 39.5 41.5 41.5 42.  45.5 49. ]
# In this interval, the return is -25847.8337040799, new principal is 866550.9878073173
# ---------------------------------------------
# Current time: 2024-03-07 20:00:00 2576
# ---------------------------------------------
# ---------------------------------------------
# For interval 28 starting at 2024-03-07 20:00:00: Long ['BNB' 'ETH' 'ATOM' 'BTC' 'DOT' 'MATIC' 'AAVE' 'CAKE' 'RUNE' 'XRP'], Short ['GALA' 'INJ' 'SEI' 'ORDI' 'MAVIA' 'SUI' 'kBONK' 'YGG' 'WLD' 'PEOPLE']
# For interval 28 starting at 2024-03-07 20:00:00: Long [12.5 14.5 16.  16.5 16.5 17.5 18.5 18.5 20.5 22.5], Short [37.5 38.  38.5 39.  39.5 40.  40.5 45.  50.5 53. ]
# In this interval, the return is -23843.919554490756, new principal is 842707.0682528266
# ---------------------------------------------
# Current time: 2024-03-08 19:00:00 2668
# ---------------------------------------------
# ---------------------------------------------
# For interval 29 starting at 2024-03-08 19:00:00: Long ['BNB' 'ETH' 'RUNE' 'BTC' 'ATOM' 'DOT' 'CAKE' 'MATIC' 'FIL' 'AAVE'], Short ['GALA' 'XAI' 'ORDI' 'STX' 'GMT' 'SUI' 'YGG' 'INJ' 'WLD' 'PEOPLE']
# For interval 29 starting at 2024-03-08 19:00:00: Long [12.5 14.  14.  16.5 17.  17.  17.5 18.5 19.5 19.5], Short [37.  37.5 38.5 39.  39.5 40.  42.  42.5 46.5 51.5]
# In this interval, the return is -60075.976484808634, new principal is 782631.091768018
# ---------------------------------------------
# Current time: 2024-03-09 18:00:00 2760
# ---------------------------------------------
# ---------------------------------------------
# For interval 30 starting at 2024-03-09 18:00:00: Long ['BNB' 'ETH' 'MKR' 'RUNE' 'BTC' 'ATOM' 'CAKE' 'DOT' 'SOL' 'MATIC'], Short ['NFTI' 'SEI' 'ALT' 'ENS' 'MEME' 'STX' 'ORDI' 'INJ' 'BCH' 'PEOPLE']
# For interval 30 starting at 2024-03-09 18:00:00: Long [11.  13.5 13.5 13.5 17.  19.5 20.  21.  22.5 23. ], Short [35.  35.  35.5 38.  39.  40.5 42.  42.  42.5 50. ]
# In this interval, the return is 14838.4310027002, new principal is 797469.5227707182
# Total simulated return over the period: -202530.47722928203

# %%
import matplotlib.pyplot as plt 
results_df.head()

# plt.figure(figsize=(14, 7))
plt.plot(results_df["timestamp"], results_df["principal"])

# %%
plt.plot(results_df["timestamp"], results_df["return"])

# %%
results_df["return"].describe()
# Out:
# count       30.000000
# mean     -6751.015908
# std      18074.665029
# min     -60075.976485
# 25%     -20673.313683
# 50%      -5076.188140
# 75%       6173.643844
# max      23134.053248
# Name: return, dtype: float64
